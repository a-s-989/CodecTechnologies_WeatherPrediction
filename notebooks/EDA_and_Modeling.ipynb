# %% [markdown]
# # EDA and Modeling
# Exploratory Data Analysis of weather data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/historical_weather.csv', parse_dates=['Date'])
df.plot(x='Date', y='Temperature', title='Temperature Over Time')
plt.show()
